# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
#Read Data and put into dataframe
df=pd.read_csv('comp.txt')
df
# Out:
#                                      Yelp Review Text  Classification  \
# 0   Let me begin by saying that there are two kind...               0
# 1   The only place inside the Loop that you can st...               1
# 2   I have walked by the Tokyo Hotel countless tim...               1
# 3   If you are considering staying here, watch thi...               0
# 4   This place is disgusting, absolutely horrible,...               0
# ..                                                ...             ...
# 95  I love this hotel. My fiance and I had our eng...               0
# 96  Classic location for smaller wedding/event wit...               0
# 97  I had my wedding (ceremony and reception) at T...               0
# 98  My wedding has happened. It happened at the Ca...               0
# 99  I cannot say enough good things about Anne Par...               0
#
#                                  Reason
# 0                                   NaN
# 1          "only place inside the loop"
# 2   "it reminds me of" "Carbon copy of"
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95                                  NaN
# 96                                  NaN
# 97                                  NaN
# 98                                  NaN
# 99                                  NaN
#
# [100 rows x 3 columns]

# %%
df2=pd.read_csv('100_Yelp_Reviews_Labelled.csv')
df2['Classification']
# Out:
# 0     0
# 1     1
# 2     1
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: Classification, Length: 100, dtype: int64

# %%
#Add the manual annotations column
selected_columns=df[" Is_Comparative? (Stanford Algorithm)"]
annotations_column=selected_columns.copy()
annotations_column
df[" Is_Comparative? (Human Annotations)"]=annotations_column
df.at[1,' Is_Comparative? (Human Annotations)']=0
df
# Out:
#     Review Number                                             Review  \
# 0               1  troubleshooting ad2500 and ad2600 no picture s...
# 1               2  repost from january 13 2004 with a better fit ...
# 2               3  does your apex dvd player only play dvd audio ...
# 3               4  or does it play audio and video but scrolling ...
# 4               5  before you try to return the player or waste h...
# ..            ...                                                ...
# 61             62                        it s not a big deal for me
# 62             63  i simply watched the extra features on another...
# 63             64  had this been my only dvd player though it wou...
# 64             65                  as it is i m keeping the machine
# 65             66  it works well enough so far for me to be satis...
#
#      Is_Comparative? (Our Algorithm)   Is_Comparative? (Stanford Algorithm)  \
# 0                                  0                                      0
# 1                                  1                                      1
# 2                                  0                                      0
# 3                                  0                                      0
# 4                                  0                                      0
# ..                               ...                                    ...
# 61                                 0                                      0
# 62                                 0                                      0
# 63                                 0                                      0
# 64                                 0                                      0
# 65                                 0                                      0
#
#      Is_Comparative? (Human Annotations)
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ..                                   ...
# 61                                     0
# 62                                     0
# 63                                     0
# 64                                     0
# 65                                     0
#
# [66 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-d2cb10eab882> in <module>
# ----> 1 X_train, X_test, y_train, ytest = train_test_split(df.data,df.target,test_size=0.30,random_state=100)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'
